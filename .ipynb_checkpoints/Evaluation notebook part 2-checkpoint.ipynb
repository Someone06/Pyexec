# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy.stats import mannwhitneyu as mwu, tmean as mean
sns.set(style="darkgrid")

# %% [markdown]
# Please specifiy the location of the CSV file that Pyexec created

# %%
data = pd.read_csv("/INSERT/PATH/TO/stats.csv")
data = data.replace([-1], pd.NA)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15198 entries, 0 to 15197
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   name                       15198 non-null  object
#  1   project_on_pypi            15198 non-null  bool
#  2   github_link_found          15198 non-null  bool
#  3   github_repo_exists         15198 non-null  bool
#  4   github_repo_created_at     15198 non-null  object
#  5   github_repo_last_updated   15198 non-null  object
#  6   github_repo_active_days    8846 non-null   float64
#  7   github_repo_age            8846 non-null   float64
#  8   has_setuppy                15198 non-null  bool
#  9   has_requirementstxt        15198 non-null  bool
#  10  has_makefile               15198 non-null  bool
#  11  has_pipfile                15198 non-null  bool
#  12  loc                        8916 non-null   float64
#  13  num_impl_files             9009 non-null   float64
#  14  num_test_files             9009 non-null   float64
#  15  average_complexity         8680 non-null   float64
#  16  min_python_version         3648 non-null   float64
#  17  dockerfile_found           15198 non-null  bool
#  18  dockerfile_source          15198 non-null  object
#  19  pip_dependency_count       5722 non-null   float64
#  20  apt_dependency_count       5722 non-null   float64
#  21  dockerimage_build_success  15198 non-null  bool
#  22  testcase_count             1928 non-null   float64
#  23  testsuit_executed          15198 non-null  bool
#  24  testsuit_result_parsed     15198 non-null  bool
#  25  failed                     689 non-null    float64
#  26  passed                     689 non-null    float64
#  27  skipped                    689 non-null    float64
#  28  xfailed                    689 non-null    float64
#  29  xpassed                    689 non-null    float64
#  30  warnings                   689 non-null    float64
#  31  errors                     689 non-null    float64
#  32  time                       689 non-null    float64
#  33  covered_lines              689 non-null    float64
#  34  num_statements             689 non-null    float64
#  35  percentage_covered         689 non-null    float64
#  36  missing_lines              689 non-null    float64
#  37  excluded_lines             689 non-null    float64
# dtypes: bool(11), float64(23), object(4)
# memory usage: 3.3+ MB

# %% [markdown]
# # RQ5: Results of successful testcase executions

# %% [markdown]
# In the total number of successful test case executions is

# %%
len(pre_success())
# Out:
# 689

# %% [markdown]
# Out of these, so many projcts have at least one test case:

# %%
len(success())
# Out:
# 682

# %%
print("At lest one passing: {}".format(len(success()[success()["passed"] > 0])))
print("At lest one failing: {}".format(len(success()[success()["failed"] > 0])))
print("At lest one xpassing: {}".format(len(success()[success()["xpassed"] > 0])))
print("At lest one xfailing: {}".format(len(success()[success()["xfailed"] > 0])))
print("At lest one skipped: {}".format(len(success()[success()["skipped"] > 0])))
print("At lest one error: {}".format(len(success()[success()["errors"] > 0])))
# Out:
# At lest one passing: 361
# At lest one failing: 107
# At lest one xpassing: 0
# At lest one xfailing: 11
# At lest one skipped: 41
# At lest one error: 323

# %%
_noerror = success()[success()["errors"] == 0]
_haserror = success()[success()["errors"] > 0]
print(len(_noerror))
print(len(_haserror))
# Out:
# 359
# 323

# %%
g = sns.displot(_noerror, discrete=True, x="testcase_count", hue="dockerfile_source", multiple="stack")
g.legend.set_title(title="Dockerfile source")
g.set(xlabel="Number of testcasese", xlim=(0,200))

# %%
g = sns.displot(_noerror, discrete=True, x="passed", hue="dockerfile_source", multiple="stack")
g.legend.set_title(title="Dockerfile source")
g.set(xlabel="Passed", xlim=(0,150))

# %%
np.median(_noerror["failed"].dropna())
# Out:
# 0.0

# %%
g = sns.displot(_noerror, discrete=True, x="failed", hue="dockerfile_source", multiple="stack")
g.legend.set_title(title="Dockerfile source")
g.set(xlabel="Failed", xlim=(0,25))

# %%
g = sns.displot(_noerror, x="percentage_covered", hue="dockerfile_source", hue_order=hor, multiple="stack")
g.legend.set_title(title="Dockerfile source")
g.set(xlabel="Percentage covered")

# %%
g = sns.relplot(data=_noerror, x="num_impl_files", y="percentage_covered", hue="dockerfile_source", hue_order=hor)
g.set(xlim=(0,70), xlabel="Lines of code", ylabel="Percentage covered")
g.legend.set_title(title="Dockerfile source")
